# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # Hides warning

# %%
df = pd.read_csv('charts.csv')

# %%
df = df.fillna(0)
df.head()
# Out:
#        date  rank               song                              artist  \
# 0  8/4/1958     1   Poor Little Fool                        Ricky Nelson
# 1  8/4/1958     2           Patricia       Perez Prado And His Orchestra
# 2  8/4/1958     3      Splish Splash                         Bobby Darin
# 3  8/4/1958     4  Hard Headed Woman  Elvis Presley With The Jordanaires
# 4  8/4/1958     5               When                         Kalin Twins
#
#    last-week  peak-rank  weeks-on-board
# 0        0.0          1               1
# 1        0.0          2               1
# 2        0.0          3               1
# 3        0.0          4               1
# 4        0.0          5               1

# %%
artistdf = df['artist'].value_counts().head(10)
print(artistdf)
# Out:
# Taylor Swift     1005
# Elton John        889
# Madonna           857
# Kenny Chesney     758
# Drake             735
# Tim McGraw        731
# Keith Urban       673
# Stevie Wonder     659
# Rod Stewart       657
# Mariah Carey      621
# Name: artist, dtype: int64

# %%
songdf = df['song'].value_counts().head(10)
print(songdf)
# Out:
# Stay               208
# Angel              205
# Heaven             194
# Hold On            189
# I Like It          188
# You                184
# Crazy              176
# Forever            164
# Happy              157
# Please Don't Go    152
# Name: song, dtype: int64

# %%
print(df[["artist", "song", "peak-rank"]].value_counts().head(10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-107e150aa30d> in <module>
# ----> 1 print(df[["artist", "song", "peak-rank"]].value_counts().head(10))
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df['date'] = df['date'].apply(pd.to_datetime)
df.set_index('date', inplace=True)
df.head()
# Out:
#             rank               song                              artist  \
# date
# 1958-08-04     1   Poor Little Fool                        Ricky Nelson
# 1958-08-04     2           Patricia       Perez Prado And His Orchestra
# 1958-08-04     3      Splish Splash                         Bobby Darin
# 1958-08-04     4  Hard Headed Woman  Elvis Presley With The Jordanaires
# 1958-08-04     5               When                         Kalin Twins
#
#             last-week  peak-rank  weeks-on-board
# date
# 1958-08-04        0.0          1               1
# 1958-08-04        0.0          2               1
# 1958-08-04        0.0          3               1
# 1958-08-04        0.0          4               1
# 1958-08-04        0.0          5               1

# %%
# df.resample('A')['artist'].agg(['first','last']) # It can be used to find the most and least listened ones.
df.resample('A').first()
# Out:
#             rank                             song  \
# date
# 1958-12-31     1                 Poor Little Fool
# 1959-12-31     1                The Chipmunk Song
# 1960-12-31     1                          El Paso
# 1961-12-31     1       Are You Lonesome To-night?
# 1962-12-31     1          The Lion Sleeps Tonight
# ...          ...                              ...
# 2017-12-31     1                          Starboy
# 2018-12-31     1                          Perfect
# 2019-12-31     1                    Thank U, Next
# 2020-12-31     1  All I Want For Christmas Is You
# 2021-12-31     1  All I Want For Christmas Is You
#
#                                         artist  last-week  peak-rank  \
# date
# 1958-12-31                        Ricky Nelson        0.0          1
# 1959-12-31    The Chipmunks With David Seville        1.0          1
# 1960-12-31                       Marty Robbins        2.0          1
# 1961-12-31  Elvis Presley With The Jordanaires        1.0          1
# 1962-12-31                          The Tokens        1.0          1
# ...                                        ...        ...        ...
# 2017-12-31      The Weeknd Featuring Daft Punk        2.0          1
# 2018-12-31                          Ed Sheeran        1.0          1
# 2019-12-31                       Ariana Grande        1.0          1
# 2020-12-31                        Mariah Carey        1.0          1
# 2021-12-31                        Mariah Carey        2.0          1
#
#             weeks-on-board
# date
# 1958-12-31               1
# 1959-12-31               6
# 1960-12-31               9
# 1961-12-31               8
# 1962-12-31               8
# ...                    ...
# 2017-12-31              14
# 2018-12-31              18
# 2019-12-31               8
# 2020-12-31              37
# 2021-12-31              43
#
# [64 rows x 6 columns]

# %%
artistdf = df['artist'].value_counts().head(10)
print(artistdf)
# Out:
# Taylor Swift     1005
# Elton John        889
# Madonna           857
# Kenny Chesney     758
# Drake             735
# Tim McGraw        731
# Keith Urban       673
# Stevie Wonder     659
# Rod Stewart       657
# Mariah Carey      621
# Name: artist, dtype: int64

# %%
songdf = df['song'].value_counts().head(10)
print(songdf)
# Out:
# Stay               208
# Angel              205
# Heaven             194
# Hold On            189
# I Like It          188
# You                184
# Crazy              176
# Forever            164
# Happy              157
# Please Don't Go    152
# Name: song, dtype: int64
